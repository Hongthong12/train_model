# %%
import cv2
import os
import time

def create_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)

def capture_images_from_video(save_dir, capture_interval=2, max_images=250):
    # Create directory to save images if it doesn't exist
    create_directory(save_dir)

    # Open the video stream (0 is the default camera)
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open video stream.")
        return

    # Set video width and height
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

    image_count = 0

    try:
        while image_count < max_images:
            # Capture frame-by-frame
            ret, frame = cap.read()
            if not ret:
                print("Error: Failed to capture image.")
                break

            # Display the frame
            cv2.imshow('Video Stream', frame)

            # Save the frame as an image
            image_path = os.path.join(save_dir, f'image_{image_count:04d}.jpg')
            cv2.imwrite(image_path, frame)
            print(f'Captured and saved {image_path}')
            image_count += 1

            # Wait for capture_interval seconds
            time.sleep(capture_interval)

            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    finally:
        # Release the video capture object and close all OpenCV windows
        cap.release()
        cv2.destroyAllWindows()

if __name__ == "__main__":
    # Example of a relative path 
    save_directory = "C:\\Users\\hfhon\\OneDrive\\Desktop\\train_model\\testing_dataset\\yrnyung"
    
    # Example of an absolute path (uncomment and modify the line below if you want to use an absolute path)
    # save_directory = "C:/path/to/your/directory/captured_images" 
    
    capture_interval_seconds = 0.1  # Capture an image every 0.2 seconds
    max_images_to_capture = 100

    capture_images_from_video(save_directory, capture_interval_seconds, max_images_to_capture)
# Out:
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0000.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0001.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0002.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0003.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0004.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0005.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0006.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0007.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0008.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0009.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0010.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0011.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0012.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0013.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0014.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0015.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0016.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0017.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0018.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0019.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0020.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0021.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0022.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0023.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0024.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0025.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0026.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0027.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0028.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0029.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0030.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0031.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0032.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0033.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0034.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0035.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0036.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0037.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0038.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0039.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0040.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0041.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0042.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0043.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0044.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0045.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0046.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0047.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0048.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0049.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0050.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0051.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0052.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0053.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0054.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0055.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0056.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0057.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0058.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0059.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0060.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0061.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0062.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0063.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0064.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0065.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0066.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0067.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0068.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0069.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0070.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0071.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0072.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0073.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0074.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0075.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0076.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0077.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0078.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0079.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0080.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0081.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0082.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0083.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0084.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0085.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0086.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0087.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0088.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0089.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0090.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0091.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0092.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0093.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0094.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0095.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0096.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0097.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0098.jpg
# Captured and saved C:\Users\hfhon\OneDrive\Desktop\train_model\testing_dataset\yrnyung\image_0099.jpg
